# %% [markdown]
# # Exploration Notebook
# Use this notebook for ad-hoc testing and retrieval inspection. and LLM inspection etc

# %% [markdown]
# ☑️ using openai/gpt-oss-120b:free in RAG

# %% [markdown]
# meta-llama/llama-3.3-70b-instruct:free

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key= os.getenv("OPENROUTER_API_KEY"),
)

completion = client.chat.completions.create(
  model="meta-llama/llama-3.3-70b-instruct:free",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 11
#       5 load_dotenv()
#       6 client = OpenAI(
#       7   base_url="https://openrouter.ai/api/v1",
#       8   api_key= os.getenv("OPENROUTER_API_KEY"),
#       9 )
# ---> 11 completion = client.chat.completions.create(
#      12   model="meta-llama/llama-3.3-70b-instruct:free",
#      13   messages=[
#      14     {
#      15       "role": "user",
#      16       "content": "What is the meaning of life?"
#      17     }
#      18   ]
#      19 )
#      20 print(completion.choices[0].message.content)
#
# File e:\Python Installation\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File e:\Python Installation\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)
#    1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File e:\Python Installation\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\Python Installation\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'meta-llama/llama-3.3-70b-instruct:free is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Venice', 'is_byok': False, 'retry_after_seconds': 29, 'retry_after_seconds_raw': 28.533, 'headers': {'Retry-After': '29'}}}, 'user_id': 'user_2yv2J7hqST8o24RxAk5YIxWLup2'}

# %% [markdown]
# poolside/laguna-xs-2.1:free

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key= os.getenv("OPENROUTER_API_KEY"),
)

# First API call with reasoning
response = client.chat.completions.create(
  model="poolside/laguna-xs-2.1:free",
  messages=[
          {
            "role": "user",
            "content": "whats the meaning of life?"
          }
        ],
  extra_body={"reasoning": {"enabled": True}}
)

# Extract the assistant message with reasoning_details
response = response.choices[0].message
print(response.content)


# Preserve the assistant message with reasoning_details
# messages = [
#   {"role": "user", "content": "How many r's are in the word 'strawberry'?"},
#   {
#     "role": "assistant",
#     "content": response.content,
#     "reasoning_details": response.reasoning_details  # Pass back unmodified
#   },
#   {"role": "user", "content": "Are you sure? Think carefully."}
# ]

# # Second API call - model continues reasoning from where it left off
# response2 = client.chat.completions.create(
#   model="poolside/laguna-xs-2.1:free",
#   messages=messages,
#   extra_body={"reasoning": {"enabled": True}}
# )
# Out:
# The question "What is the meaning of life?" is one of humanity’s oldest and most profound inquiries. There is no single, universally agreed-upon answer—instead, it has been explored through philosophy, religion, science, art, and personal experience. Here’s a snapshot of various perspectives:
#
# ---
#
# ### **1. Philosophical Perspectives**
# - **Existentialism**: Thinkers like Jean-Paul Sartre and Albert Camus argue that life has no inherent meaning, but humans can *create* their own purpose through choices, actions, and commitments. As Camus wrote, *"The struggle itself toward the heights is enough to fill a man’s heart. One must imagine Sisyphus happy."*
# - **Absurdism**: The idea that the search for meaning clashes with a meaningless universe, but we can embrace this contradiction and find joy in the journey.
# - **Stoicism**: Focus on virtue, reason, and living in harmony with nature. Meaning comes from self-mastery and contributing to the greater good.
#
# ---
#
# ### **2. Religious and Spiritual Views**
# - **Abrahamic Religions** (Christianity, Islam, Judaism): Life’s purpose is often tied to serving God, following divine laws, and preparing for an afterlife.
# - **Eastern Traditions** (Buddhism, Hinduism): Life is a cycle of suffering (*dukkha*) driven by desire. The goal is to transcend this cycle (*moksha* or *nirvana*) through enlightenment, karma, and detachment.
# - **Indigenous Spiritualities**: Often emphasize interconnectedness with nature, community, and ancestral wisdom.
#
# ---
#
# ### **3. Scientific and Evolutionary Perspectives**
# - **Biology**: Life’s "purpose" is survival and reproduction—passing on genes to the next generation. Evolution doesn’t aim for meaning, just adaptation.
# - **Cosmic Perspective**: Carl Sagan and others suggest we’re stardust seeking to understand itself. The universe doesn’t have a purpose, but consciousness lets us create meaning in an indifferent cosmos.
#
# ---
#
# ### **4. Humanistic and Psychological Views**
# - **Self-Actualization** (Maslow): Meaning comes from fulfilling one’s potential, creativity, and personal growth.
# - **Positive Psychology**: Meaning is found in relationships, gratitude, and contributing to something larger than oneself.
# - **Narrative Identity**: We construct stories about our lives to make sense of our experiences and find coherence in chaos.
#
# ---
#
# ### **5. Pop Culture and Humor**
# - **The Answer to Life, the Universe, and Everything** (Douglas Adams’ *The Hitchhiker’s Guide to the Galaxy*): A supercomputer calculates that the answer is "42"—a humorous reminder that the question itself is more important than any definitive answer.
# - **Existential Comedy**: Shows like *The Good Place* or *BoJack Horseman* explore themes of redemption, identity, and finding purpose in a chaotic world.
#
# ---
#
# ### **6. Personal and Subjective Meaning**
# Ultimately, many argue that meaning is deeply personal. It might come from:
# - **Love and connection** (relationships, family, community).
# - **Creation and expression** (art, writing, innovation).
# - **Service and impact** (helping others, social justice).
# - **Curiosity and growth** (learning, exploration, self-improvement).
# - **Even suffering** (finding strength or purpose in hardship).
#
# ---
#
# ### **A Thought to Carry Forward**
# As the poet Mary Oliver asked, *"Tell me, what is it you plan to do with your one wild and precious life?"* The search for meaning might itself be the meaning. Whether through faith, reason, love, or rebellion against the void, the act of seeking—questioning, creating, and connecting—is what gives life its depth.
#
# What do *you* think gives your life meaning? 🚀

# %% [markdown]
# qwen/qwen3-next-80b-a3b-instruct:free

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key= os.getenv("OPENROUTER_API_KEY"),
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-OpenRouter-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  extra_body={},
  model="qwen/qwen3-next-80b-a3b-instruct:free",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[10], line 11
#       5 load_dotenv()
#       6 client = OpenAI(
#       7   base_url="https://openrouter.ai/api/v1",
#       8   api_key= os.getenv("OPENROUTER_API_KEY"),
#       9 )
# ---> 11 completion = client.chat.completions.create(
#      12   extra_headers={
#      13     "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
#      14     "X-OpenRouter-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
#      15   },
#      16   extra_body={},
#      17   model="qwen/qwen3-next-80b-a3b-instruct:free",
#      18   messages=[
#      19     {
#      20       "role": "user",
#      21       "content": "What is the meaning of life?"
#      22     }
#      23   ]
#      24 )
#      25 print(completion.choices[0].message.content)
#
# File e:\Python Installation\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File e:\Python Installation\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)
#    1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File e:\Python Installation\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\Python Installation\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'qwen/qwen3-next-80b-a3b-instruct:free is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Venice', 'is_byok': False, 'retry_after_seconds': 29, 'retry_after_seconds_raw': 28.454, 'headers': {'Retry-After': '29'}}}, 'user_id': 'user_2yv2J7hqST8o24RxAk5YIxWLup2'}

# %% [markdown]
# openai/gpt-oss-120b:free

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key= os.getenv("OPENROUTER_API_KEY"),
)

# First API call with reasoning
response = client.chat.completions.create(
  model="openai/gpt-oss-120b:free",
  messages=[
          {
            "role": "user",
            "content": "whats the meaning of the life?"
          }
        ],
  extra_body={"reasoning": {"enabled": True}}
)

# Extract the assistant message with reasoning_details
response = response.choices[0].message
print(response.content)
# # Preserve the assistant message with reasoning_details
# messages = [
#   {"role": "user", "content": "How many r's are in the word 'strawberry'?"},
#   {
#     "role": "assistant",
#     "content": response.content,
#     "reasoning_details": response.reasoning_details  # Pass back unmodified
#   },
#   {"role": "user", "content": "Are you sure? Think carefully."}
# ]

# # Second API call - model continues reasoning from where it left off
# response2 = client.chat.completions.create(
#   model="openai/gpt-oss-120b:free",
#   messages=messages,
#   extra_body={"reasoning": {"enabled": True}}
# )
# Out:
# The question “What’s the meaning of life?” has been asked for millennia, and there’s no single answer that satisfies everyone. Instead, people tend to find meaning through a mixture of cultural narratives, personal experiences, and philosophical frameworks. Below are some of the most influential ways thinkers have approached the question, along with practical ideas you can experiment with to discover what feels most resonant for you.
#
# ---
#
# ## 1. Big‑Picture Philosophical Views
#
# | School of thought | Core claim about life’s meaning | Typical “take‑away” for everyday living |
# |-------------------|--------------------------------|----------------------------------------|
# | **Existentialism** (e.g., Sartre, Camus) | Life has no pre‑ordained purpose; meaning is created by each individual through choices. | Embrace freedom, accept responsibility for your projects, and craft a personal narrative that matters to you. |
# | **Nihilism** (e.g., some interpretations of Nietzsche) | There is no inherent meaning, value, or purpose. | Some people find liberation in that “nothing matters,” allowing them to pursue pleasure or curiosity without guilt. |
# | **Absurdism** (Camus) | The human search for meaning collides with a silent universe—this tension is the “absurd.” | Respond by rebelling against the absurd: engage fully, create art, love deeply, and find joy despite the lack of cosmic script. |
# | **Humanism** | Meaning is found in human flourishing, relationships, and the betterment of society. | Focus on empathy, education, social justice, and contributing to the collective well‑being. |
# | **Transcendental/Spiritual** (e.g., many Eastern traditions) | Life’s purpose is to realize a deeper reality—union with the divine, enlightenment, or the dissolution of ego. | Practices like meditation, mindfulness, prayer, or service help you “see through” ordinary concerns to a larger sense of oneness. |
# | **Theistic (monotheistic religions)** | Meaning is grounded in a relationship with a personal God who has a plan for humanity. | Follow the moral and ritual teachings of your faith, seek divine purpose, and view life as a pilgrimage toward an eternal destination. |
# | **Evolutionary/Scientific** | Meaning is a by‑product of biological imperatives (survival, reproduction) and cultural evolution. | Find significance in the wonder of being a product of the cosmos, and use our unique consciousness to explore, create, and understand. |
#
# *Takeaway:* You don’t have to adopt an entire worldview wholesale; you can cherry‑pick ideas that click for you and blend them into a personal philosophy.
#
# ---
#
# ## 2. Common Sources of Personal Meaning
#
# 1. **Relationships** – Love, friendship, family, and community often top the list in surveys (e.g., Pew Research, World Happiness Report). The sense of being known and caring for others gives life a concrete anchor.
#
# 2. **Growth & Mastery** – Learning new skills, pursuing education, or honing a craft can feel profoundly purposeful. The *process* of improvement offers a continual “why.”
#
# 3. **Contribution & Service** – Helping others—whether through paid work, volunteering, or simple daily kindness—creates the feeling that you matter beyond yourself.
#
# 4. **Creativity & Expression** – Art, music, writing, design, or any act of creation lets you leave a personal imprint on the world.
#
# 5. **Transcendence & Awe** – Experiences that lift you out of the ordinary—nature, art, the night sky, profound meditation—can generate a sense of belonging to something larger.
#
# 6. **Narrative & Storytelling** – Framing your life as a story (with challenges, turning points, and aspirations) helps you see coherence and direction.
#
# 7. **Physical Embodiment** – Caring for the body through movement, nutrition, and sleep not only improves health but also reinforces a feeling that you are *present* in your own life.
#
# ---
#
# ## 3. A Simple Exercise to Find Your Own “Why”
#
# 1. **Write a “Meaning Map.”**
#    - Draw a central circle labeled *Me*.
#    - Branch out with circles for *People*, *Passions*, *Values*, *Accomplishments*, and *Experiences*.
#    - Fill each with concrete items: name a loved one, a hobby you love, a principle you won’t compromise, a moment you felt alive, etc.
#
# 2. **Identify Patterns.**
#    - Which categories have the most entries?
#    - Do certain words appear repeatedly (e.g., “connection,” “growth,” “beauty”)?
#
# 3. **Craft a Personal Mission Statement.**
#    - Example: “I aim to nurture deep relationships, keep learning about the natural world, and share stories that inspire curiosity.”
#    - Keep it short, revisable, and actionable.
#
# 4. **Test & Iterate.**
#    - Over the next month, do one small thing each week that aligns with your statement.
#    - Notice how it feels. Adjust the statement if something feels forced or missing.
#
# ---
#
# ## 4. What If You Feel “Stuck”?
#
# - **Loneliness:** Seek out groups (clubs, meet‑ups, online communities) centered around an interest you love. Even a single regular meet‑up can shift the sense of purpose.
# - **Boredom/Monotony:** Add novelty. Try a “30‑day skill challenge,” travel to a new place, or change your daily routine.
# - **Existential dread:** Read literature that grapples with the same feelings—Camus’s *The Myth of Sisyphus*, Viktor Frankl’s *Man’s Search for Meaning*, or modern works like *The Little Book of Atheist Spirituality*. Seeing how others have wrestled with the question can normalize it and provide new angles.
#
# ---
#
# ## 5. Quick Takeaways (Bullet Summary)
#
# - **No universal answer**—meaning is a personal construction built on cultural, philosophical, and experiential foundations.
# - **Common anchors**: relationships, growth, contribution, creativity, awe, narrative, embodied health.
# - **Practical step**: map your life’s elements, spot recurring themes, and write a tentative mission statement you can test.
# - **Flexibility**: Your sense of meaning can evolve; it’s healthy to revisit and revise your “why.”
# - **If you feel lost**, try community, novelty, or reading existential literature to gain perspective.
#
# ---
#
# ### A final thought
#
# Whether you view life as a story you author, a garden you tend, or a fleeting spark in a vast universe, the search itself is a core part of the human experience. Embracing the quest—asking, experimenting, learning, loving—can be as meaningful as any final answer you might eventually settle on.
#
# If you’d like help brainstorming concrete actions around any of the sources of meaning above (e.g., “How can I build deeper friendships?” or “What low‑cost ways can I start creating art?”), just let me know!
